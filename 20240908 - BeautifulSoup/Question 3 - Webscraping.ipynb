# %%
# !pip install bs4
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests

# %%
import pandas as pd

# %%
dineout = requests.get('https://www.dineout.co.in/')
print (dineout.send_code)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 2
#       1 dineout = requests.get('https://www.dineout.co.in/')
# ----> 2 print (dineout.send_code)
#
# AttributeError: 'Response' object has no attribute 'send_code'

# %%
dineout = requests.get('https://www.dineout.co.in/')
print(dineout.status_code)
# Out:
# 200

# %%
print(page.text)
# Out:
# <!DOCTYPE html><html lang="en"><head><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="full-screen" content="yes"/><meta name="theme-color" content="#FFFFFF"/><meta name="mobile-web-app-capable" content="yes"/><meta name="apple-mobile-web-app-capable" content="yes"/><meta name="apple-mobile-web-app-status-bar-style" content="default"/><meta name="apple-mobile-web-app-title" content="Dineout"/><link rel="icon" type="image/x-icon" href="/static/img/favicon.ico"/><link rel="icon" sizes="192x192" href="https://im1.dineout.co.in/images/uploads/misc/2019/Apr/26/android-icon-192r.png"/><link rel="apple-touch-icon" sizes="192x192" href="https://im1.dineout.co.in/images/uploads/misc/2019/Apr/26/android-icon-192r.png"/><meta name="google-site-verification" content="CTeXuUDPJxcVXw2x0JZKk4dthXMp1kunCryiPzse1Uk"/><link rel="preconnect" href="https://dn1.dineout-cdn.co.in"/><link rel="preconnect" href="https://im1.dineout.co.in"/><link rel="preconnect" href="
# ...

# %%
soup = BeautifulSoup(page.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
# i) restuarant_name
restuarant_name = soup.find('div', class_="restnt-info cursor"):
print(restuarant_name)
# Out:
#   Cell In[46], line 2
#     restuarant_name = soup.find('div', class_="restnt-info cursor"):
#                                                                    ^
# SyntaxError: invalid syntax

# %%
# i) restuarant_name

restuarant_name = []
for i in soup.find_all('div', class_="restnt-info cursor"):
    restuarant_name.append(i.text)


restuarant_name
# Out:
# []

# %%
restuarant_name.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 restuarant_name.text
#
# AttributeError: 'list' object has no attribute 'text'

# %%
# ii) Image
images = []
for i in soup.find_all('div', class_="_2DVRC"):
    images.append(i.get['data-src'])

images
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 # ii) Image
#       2 images = []
# ----> 3 for i in soup.find_all('div', class_="_2DVRC"):
#       4     images.append(i.get['data-src'])
#       6 images
#
# NameError: name 'soup' is not defined

# %%
images = []
for i in soup.find_all('div', class_="_2DVRC"):
    images.append(i.get('data-src'))

images
# Out:
# []

# %%
# iii) location

location = soup.find_all('div', class_="restnt-loc ellipsis")
location
# Out:
# []

# %%
# iv) rating

rating = soup.find_all('div', class_="restnt-rating rating-4")
rating
# Out:
# []

# %%
# v) Image URL

image_url = soup.find_all('img', {'data-src':"https://im1.dineout.co.in/images/uploads/restaurant/sharpen/1/d/f/p19636-16463919576221f295ae1f1.jpg?tr=tr:n-medium"})
image_url
# Out:
# []
